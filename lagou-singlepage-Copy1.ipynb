# %%
import pandas as pd
import urllib
import re
import requests

# %%
from bs4 import BeautifulSoup

# %%
from distutils.filelist import findall

# %% [markdown]
# https://www.lagou.com/jobs/list_%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90?labelWords=&fromSearch=true&suginput=

# %% [markdown]
# {'companyId': 917, 'positionName': '数据分析师 (上海)', 'workYear': '1-3年', 'education': '本科', 'jobNature': '全职', 'financeStage': 'D轮及以上', 'companyLogo': 'i/image/M00/37/20/CgqKkVdfms6Ac6dNAABY3gBvuqI944.jpg', 'industryField': '移动互联网,数据服务', 'city': '上海', 'salary': '10k-20k', 'positionId': 3942319, 'positionAdvantage': 'D轮+,14薪+,攻城狮氛围,弹性工作', 'companyShortName': '极光', 'district': '普陀区', 'createTime': '2018-03-15 20:46:13', 'score': 0, 'approve': 1, 'positionLables': ['中级', '算法', '数据挖掘', '机器学习', '建模'], 'industryLables': [], 'publisherId': 2153176, 'companyLabelList': ['五险一金', '文体活动', '团建旅游', '美味晚餐'], 'companySize': '150-500人', 'businessZones': ['曹杨', '石泉路', '中山北路', '石泉路', '曹杨', '石泉路', '中山北路', '曹杨', '中山北路'], 'longitude': '121.419056', 'latitude': '31.254915', 'hitags': None, 'resumeProcessRate': 100, 'resumeProcessDay': 1, 'imState': 'today', 'lastLogin': 1521117963000, 'explain': None, 'plus': None, 'pcShow': 0, 'appShow': 0, 'deliver': 0, 'gradeDescription': None, 'promotionScoreExplain': None, 'firstType': '开发/测试/运维类', 'secondType': '数据开发', 'isSchoolJob': 0, 'subwayline': '11号线(花桥)', 'stationname': '新村路', 'linestaion': '3号线_镇坪路;4号线_镇坪路;7号线_镇坪路;7号线_岚皋路;7号线_新村路;11号线(嘉定北)_真如;11号线(花桥)_真如', 'formatCreateTime': '20:46发布', 'companyFullName': '深圳市和讯华谷信息技术有限公司', 'adWord': 0}

# %%
df = pd.DataFrame({'companyID':[],
                  'companyShortName':[],
                  'salary':[],
                  'isSchoolJob':[],
                  'jobNature':[],
                  'industryField':[],
                  'workYear':[],
                  'education':[],
                  'createTime':[],
                   'score':[]
                  })

# %%
headers = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36',
    'Host':'www.lagou.com',
    'Referer':'https://www.lagou.com/jobs/list_%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90?labelWords=&fromSearch=true&suginput=',
    'X-Anit-Forge-Code':'0',
    'X-Anit-Forge-Token':'None',
    'X-Requested-With':'XMLHttpRequest'
    
}
from_data = {
    'first':'true',
    'pn':'6',
    'kd':'数据分析'
}
result = requests.post('https://www.lagou.com/jobs/positionAjax.json?city=%E4%B8%8A%E6%B5%B7&needAddtionalResult=false&isSchoolJob=0',
                     headers = headers,data=from_data)
json_result = result.json()
positions = json_result['content']['positionResult']['result']
#print (positions)
print (len(positions))
for position in positions:
    companyID = position['companyId']
    companyShortName = position['companyShortName']
    salary = position['salary']
    isSchoolJob = position['isSchoolJob']
    jobNature = position['jobNature']
    industryField = position['industryField']
    #positionLables = position['positionLables']
    workYear = position['workYear']
    education = position['education']
    createTime = position['createTime']
    score = position['score']


    #print (position)
    #print ('-'*30)
    dfa = pd.DataFrame({'companyID':companyID,'companyShortName':companyShortName,'salary':salary,
                        'isSchoolJob':isSchoolJob,'jobNature':jobNature,'industryField':industryField,
                        #'positionLables':positionLables
                        'workYear':workYear,'education':education,'createTime':createTime,'score':score
                       },index= ['1'])
    df = df.append(dfa,ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-d5e08f34b8b6> in <module>()
#      16                      headers = headers,data=from_data)
#      17 json_result = result.json()
# ---> 18 positions = json_result['content']['positionResult']['result']
#      19 #print (positions)
#      20 print (len(positions))
#
# KeyError: 'content'

# %%
df
# Out:
#     companyID companyShortName           createTime education industryField  \
# 0      3038.0       Gridsum 国双  2018-03-16 10:08:16        本科     数据服务,企业服务
# 1     33618.0              微贷网  2018-03-10 18:49:34        本科            金融
# 2      3422.0            英语流利说  2018-03-16 13:29:25        本科      移动互联网,教育
# 3       917.0               极光  2018-03-16 14:01:51        本科    移动互联网,数据服务
# 4      3864.0          51信用卡管家  2018-03-13 14:19:52        本科       金融,数据服务
# 5     24748.0             平安科技  2018-03-16 09:17:15        本科            金融
# 6    137839.0             万家医疗  2018-03-16 09:19:52        本科          医疗健康
# 7      4760.0              唯品会  2018-03-16 12:29:53        本科          电子商务
# 8    119042.0             鸿特普惠  2018-03-14 09:43:13        本科            金融
# 9      4448.0               挖财  2018-03-16 10:35:59        不限      移动互联网,金融
# 10   316814.0              享物说  2018-03-15 18:43:42        本科    移动互联网 生活服务
# 11     1686.0              爱奇艺  2018-03-11 23:50:09        本科     广告营销,文化娱乐
# 12     4112.0             韩创科技  2018-03-15 10:08:00        不限    移动互联网,文化娱乐
# 13    36009.0            途虎养车网  2018-03-15 16:20:57        本科         移动互联网
# 14   159688.0             口袋理财  2018-03-16 15:01:20        本科      金融,移动互联网
# 15     3422.0            英语流利说  2018-03-16 15:19:30        本科      移动互联网,教育
# 16    16875.0             东方国信  2018-03-14 16:25:24        本科          数据服务
# 17     1686.0              爱奇艺  2018-03-13 10:08:13        本科     广告营销,文化娱乐
# 18   164989.0             哈罗单车  2018-03-16 12:25:37        本科      移动互联网,硬件
# 19   139755.0             京东商城  2018-02-24 18:49:20        本科          电子商务
# 20    57353.0       中移在线服务有限公司  2018-03-15 18:59:23        本科         移动互联网
# 21     4448.0               挖财  2018-03-16 10:36:07        本科      移动互联网,金融
# 22   251737.0              享换机  2018-03-15 11:41:53        本科      移动互联网,金融
# 23     6044.0              拍拍贷  2018-03-16 10:58:53        本科            金融
# 24    73937.0         上海第一财经数据  2018-03-14 18:12:55        本科         移动互联网
# 25    32836.0          达达-京东到家  2018-03-15 15:37:53        本科           O2O
# 26    35713.0         链家上海研发中心  2018-03-15 20:42:02        本科          企业服务
# 27    38480.0              超爱财  2018-03-15 16:46:36        本科            金融
# 28    47956.0             厚本金融  2018-03-16 10:09:12        本科            金融
# 29     3038.0       Gridsum 国双  2018-03-13 10:54:02        本科     数据服务,企业服务
# ..        ...              ...                  ...       ...           ...
# 45     4950.0  好买基金网（联想腾讯注资企业）  2018-03-15 09:11:52        本科       电子商务,金融
# 46   126031.0         Datatist  2018-03-16 09:44:06        硕士     数据服务,广告营销
# 47    35713.0         链家上海研发中心  2018-03-15 20:42:00        硕士          企业服务
# 48     4448.0               挖财  2018-03-16 10:36:01        本科      移动互联网,金融
# 49    66311.0              方付通  2018-03-15 13:54:17        本科      移动互联网,金融
# 50    50702.0             美团点评  2018-03-16 11:40:25        本科     移动互联网,O2O
# 51   105718.0          平安健康互联网  2018-03-16 10:30:54        本科    移动互联网,医疗健康
# 52   236071.0            奥动新能源  2018-03-16 14:58:13        本科         移动互联网
# 53   164989.0             哈罗单车  2018-03-16 12:25:32        本科      移动互联网,硬件
# 54    83811.0           上海融腾集团  2018-03-16 10:55:29        本科            金融
# 55    13163.0               个推  2018-03-16 14:13:36        本科         移动互联网
# 56   144037.0              眸事网  2018-03-16 09:43:41        本科    移动互联网,企业服务
# 57    92943.0              木七七  2018-03-13 16:01:32        本科      移动互联网,游戏
# 58    47956.0             厚本金融  2018-03-16 10:09:10        硕士            金融
# 59    73604.0            萨摩耶金服  2018-03-15 16:00:34        本科            金融
# 60   164989.0             哈罗单车  2018-03-16 12:25:36        本科      移动互联网,硬件
# 61   249959.0              壹现金  2018-03-01 11:54:01        本科      金融,移动互联网
# 62    83811.0           上海融腾集团  2018-03-16 10:55:30        本科            金融
# 63    51235.0             麦图科技  2018-03-14 15:25:20        本科          数据服务
# 64   103163.0         高登世德金融科技  2018-03-14 11:55:26        本科       金融,数据服务
# 65    30843.0            ezbuy  2018-03-16 10:47:08        大专     电子商务,生活服务
# 66     6044.0              拍拍贷  2018-03-15 11:31:35        本科            金融
# 67   251737.0              享换机  2018-03-15 11:41:53        本科      移动互联网,金融
# 68    30816.0             蜻蜓FM  2018-03-14 10:24:52        不限         移动互联网
# 69    23348.0             中通快递  2018-03-08 09:11:01        大专          电子商务
# 70    13163.0               个推  2018-03-16 14:13:34        本科         移动互联网
# 71    35713.0         链家上海研发中心  2018-03-15 20:42:00        本科          企业服务
# 72    34683.0              买单侠  2018-03-16 14:48:05        本科      移动互联网、金融
# 73    29211.0               圆通  2018-03-16 09:08:21        本科     企业服务,数据服务
# 74    41258.0     国泰君安证券股份有限公司  2018-03-12 16:48:33        硕士            金融
#
#     isSchoolJob jobNature   salary  score workYear
# 0           0.0        全职   8k-15k    0.0     3-5年
# 1           0.0        全职  15k-24k    0.0     3-5年
# 2           0.0        全职  15k-30k    0.0       不限
# 3           0.0        全职  10k-20k    0.0     1-3年
# 4           0.0        全职  10k-20k    0.0     1-3年
# 5           0.0        全职  10k-15k    0.0       不限
# 6           0.0        全职  10k-20k    0.0     1-3年
# 7           0.0        全职  30k-45k    0.0    5-10年
# 8           0.0        全职   6k-12k    0.0     1-3年
# 9           0.0        实习    2k-3k    0.0       不限
# 10          0.0        全职  20k-40k    0.0     3-5年
# 11          0.0        全职   7k-12k    0.0     1-3年
# 12          0.0        全职   8k-16k    0.0     3-5年
# 13          0.0        全职  20k-40k    0.0    5-10年
# 14          0.0        全职  15k-25k    0.0     3-5年
# 15          0.0        全职    6k-8k    0.0     1-3年
# 16          0.0        全职   8k-15k    0.0     3-5年
# 17          0.0        全职   8k-15k    0.0     1-3年
# 18          0.0        全职  15k-30k    0.0     3-5年
# 19          0.0        全职  15k-30k    0.0     3-5年
# 20          0.0        全职  20k-25k    0.0     3-5年
# 21          0.0        全职  12k-24k    0.0     1-3年
# 22          0.0        全职  15k-30k    0.0     3-5年
# 23          0.0        全职  20k-30k    0.0    5-10年
# 24          0.0        全职  10k-15k    0.0     1-3年
# 25          0.0        全职  15k-25k    0.0     3-5年
# 26          0.0        全职   9k-15k    0.0     1-3年
# 27          0.0        全职  15k-25k    0.0     3-5年
# 28          0.0        全职    7k-9k    0.0     1-3年
# 29          0.0        全职  10k-20k    0.0    5-10年
# ..          ...       ...      ...    ...      ...
# 45          0.0        全职  15k-20k    0.0     1-3年
# 46          0.0        全职   8k-16k    0.0     1-3年
# 47          0.0        全职  10k-19k    0.0     1-3年
# 48          0.0        全职  15k-25k    0.0     3-5年
# 49          0.0        全职  15k-30k    0.0     3-5年
# 50          0.0        全职  15k-30k    0.0     3-5年
# 51          0.0        全职  15k-30k    0.0     3-5年
# 52          0.0        全职  15k-25k    0.0    5-10年
# 53          0.0        全职  25k-35k    0.0    5-10年
# 54          0.0        全职  12k-24k    0.0     3-5年
# 55          0.0        全职  20k-25k    0.0     3-5年
# 56          0.0        全职   8k-12k    0.0     1-3年
# 57          0.0        全职   8k-10k    0.0     1-3年
# 58          0.0        全职  15k-30k    0.0     3-5年
# 59          0.0        全职  13k-25k    0.0     3-5年
# 60          0.0        全职  15k-30k    0.0     3-5年
# 61          0.0        全职    6k-9k    0.0     1-3年
# 62          0.0        全职  15k-30k    0.0     3-5年
# 63          0.0        全职  10k-15k    0.0       不限
# 64          0.0        全职   8k-15k    0.0     1-3年
# 65          0.0        全职  15k-25k    0.0     3-5年
# 66          0.0        全职  15k-20k    0.0     1-3年
# 67          0.0        全职  15k-30k    0.0     3-5年
# 68          0.0        全职  18k-30k    0.0     1-3年
# 69          0.0        全职  15k-30k    0.0    5-10年
# 70          0.0        全职  15k-25k    0.0     1-3年
# 71          0.0        全职  20k-30k    0.0    5-10年
# 72          0.0        全职  10k-18k    0.0     3-5年
# 73          0.0        全职   8k-15k    0.0     1-3年
# 74          0.0        全职  20k-40k    0.0     3-5年
#
# [75 rows x 10 columns]

# %%
df.to_csv('lagou.csv',sep=',',header=True,encoding='gb18030')
